# %% [markdown]
# *   Computing Platforms: Set up the Workspace for Machine Learning Projects.  https://ms.pubpub.org/pub/computing
# *  Machine Learning for Predictions. https://ms.pubpub.org/pub/ml-prediction
# * Machine Learning Packages: https://scikit-learn.org/stable/

# %% [markdown]
# # Part I: Import and Inspect Data

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Rising-Stars-by-Sunshine/stats201-tutorial-prediction/main/data/Queried_Data/queried_data.csv',index_col="Unnamed: 0")
df.head()
# Out:
#        number            timestamp  gas_used  gas_limit
# 100  14650515  2022-04-25 00:00:04         0   30000000
# 101  14650516  2022-04-25 00:00:07   3067277   29970705
# 102  14650517  2022-04-25 00:00:09  29927116   29941438
# 103  14650518  2022-04-25 00:00:35  29951281   29970676
# 104  14650519  2022-04-25 00:00:38  15598681   29999943

# %% [markdown]
# # Part II: Prepare the Y varible for Regression

# %% [markdown]
# ## 2.1. Write functions to calculte the Y variable for Regression
#
# *(skip the step if the Y variable already exists)*

# %%
df['theta'] = df['gas_used']/df['gas_limit']
df.head()
# Out:
#        number            timestamp  gas_used  gas_limit     theta
# 100  14650515  2022-04-25 00:00:04         0   30000000  0.000000
# 101  14650516  2022-04-25 00:00:07   3067277   29970705  0.102343
# 102  14650517  2022-04-25 00:00:09  29927116   29941438  0.999522
# 103  14650518  2022-04-25 00:00:35  29951281   29970676  0.999353
# 104  14650519  2022-04-25 00:00:38  15598681   29999943  0.519957

# %% [markdown]
# ## 2.2. Make Sure that the Data Type of Y is "numeric"

# %%
df.dtypes
# Out:
# number         int64
# timestamp     object
# gas_used       int64
# gas_limit      int64
# theta        float64
# dtype: object

# %%
df['theta'] = pd.to_numeric(df['theta'])
df.dtypes
# Out:
# number         int64
# timestamp     object
# gas_used       int64
# gas_limit      int64
# theta        float64
# dtype: object

# %% [markdown]
# # Part III: Prepare the Y variable for Classification

# %% [markdown]
# reference:
#
# https://datatofish.com/if-condition-in-pandas-dataframe/ *italicized text*

# %%
#@title Define the Congestion Threshold
cut = 0.95 #@param {type:"number"}

# %%
df['congested'] = df['theta'] >= cut
df.head()
# Out:
#        number            timestamp  gas_used  gas_limit     theta  congested
# 100  14650515  2022-04-25 00:00:04         0   30000000  0.000000      False
# 101  14650516  2022-04-25 00:00:07   3067277   29970705  0.102343      False
# 102  14650517  2022-04-25 00:00:09  29927116   29941438  0.999522       True
# 103  14650518  2022-04-25 00:00:35  29951281   29970676  0.999353       True
# 104  14650519  2022-04-25 00:00:38  15598681   29999943  0.519957      False

# %%
df.loc[(df['theta'] >= cut), 'congested'] = 1
df.loc[(df['theta'] <cut), 'congested'] = 0
df.head()
# Out:
#        number            timestamp  gas_used  gas_limit     theta congested
# 100  14650515  2022-04-25 00:00:04         0   30000000  0.000000         0
# 101  14650516  2022-04-25 00:00:07   3067277   29970705  0.102343         0
# 102  14650517  2022-04-25 00:00:09  29927116   29941438  0.999522         1
# 103  14650518  2022-04-25 00:00:35  29951281   29970676  0.999353         1
# 104  14650519  2022-04-25 00:00:38  15598681   29999943  0.519957         0

# %% [markdown]
# # 3.3. Method 3: Lambda function

# %%
df['congested'] = df['theta'].apply(lambda x: 1 if x>= cut else 0)
df.head()
# Out:
#        number            timestamp  gas_used  gas_limit     theta  congested
# 100  14650515  2022-04-25 00:00:04         0   30000000  0.000000          0
# 101  14650516  2022-04-25 00:00:07   3067277   29970705  0.102343          0
# 102  14650517  2022-04-25 00:00:09  29927116   29941438  0.999522          1
# 103  14650518  2022-04-25 00:00:35  29951281   29970676  0.999353          1
# 104  14650519  2022-04-25 00:00:38  15598681   29999943  0.519957          0

# %% [markdown]
# ## 3.2. Method 2: Cut function

# %% [markdown]
# reference:
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.cut.html

# %%
df.head()
# Out:
#        number            timestamp  gas_used  gas_limit     theta  congested
# 100  14650515  2022-04-25 00:00:04         0   30000000  0.000000          0
# 101  14650516  2022-04-25 00:00:07   3067277   29970705  0.102343          0
# 102  14650517  2022-04-25 00:00:09  29927116   29941438  0.999522          1
# 103  14650518  2022-04-25 00:00:35  29951281   29970676  0.999353          1
# 104  14650519  2022-04-25 00:00:38  15598681   29999943  0.519957          0

# %%
import numpy as np
 
congested = pd.cut(df['theta'], bins=[0,0.95,1], labels=[0,1]) #might have problems at boundaries
df.insert(3, 'congested2',congested)
df.head()
# Out:
#        number            timestamp  gas_used congested2  gas_limit     theta  \
# 100  14650515  2022-04-25 00:00:04         0        NaN   30000000  0.000000
# 101  14650516  2022-04-25 00:00:07   3067277          0   29970705  0.102343
# 102  14650517  2022-04-25 00:00:09  29927116          1   29941438  0.999522
# 103  14650518  2022-04-25 00:00:35  29951281          1   29970676  0.999353
# 104  14650519  2022-04-25 00:00:38  15598681          0   29999943  0.519957
#
#      congested
# 100          0
# 101          0
# 102          1
# 103          1
# 104          0

# %% [markdown]
# # Part III: Create the X variables

# %% [markdown]
# ## 3.1. Shift the Y to get past values

# %% [markdown]
# reference:
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.shift.html

# %%
df['theta_past'] =df['theta'].shift(1)
df.head()
# Out:
#        number            timestamp  gas_used congested2  gas_limit     theta  \
# 100  14650515  2022-04-25 00:00:04         0        NaN   30000000  0.000000
# 101  14650516  2022-04-25 00:00:07   3067277          0   29970705  0.102343
# 102  14650517  2022-04-25 00:00:09  29927116          1   29941438  0.999522
# 103  14650518  2022-04-25 00:00:35  29951281          1   29970676  0.999353
# 104  14650519  2022-04-25 00:00:38  15598681          0   29999943  0.519957
#
#      congested  theta_past
# 100          0         NaN
# 101          0    0.000000
# 102          1    0.102343
# 103          1    0.999522
# 104          0    0.999353

# %% [markdown]
# ## 3.2. Calculate the Moving Averages
#
# references:
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rolling.html

# %%
#@title Define the Window
window = 10 #@param {type:"number"}

# %%
df['theta_past_ma10']=df['theta_past'].rolling(window=window).mean()
df.head(20)
# Out:
#        number            timestamp  gas_used congested2  gas_limit     theta  \
# 100  14650515  2022-04-25 00:00:04         0        NaN   30000000  0.000000
# 101  14650516  2022-04-25 00:00:07   3067277          0   29970705  0.102343
# 102  14650517  2022-04-25 00:00:09  29927116          1   29941438  0.999522
# 103  14650518  2022-04-25 00:00:35  29951281          1   29970676  0.999353
# 104  14650519  2022-04-25 00:00:38  15598681          0   29999943  0.519957
# 105  14650520  2022-04-25 00:00:47  10844553          0   30000000  0.361485
# 106  14650521  2022-04-25 00:00:52   7476517          0   30000000  0.249217
# 107  14650522  2022-04-25 00:00:56         0        NaN   30000000  0.000000
# 108  14650523  2022-04-25 00:00:57  18525539          0   30000000  0.617518
# 109  14650524  2022-04-25 00:01:01  10934632          0   30000000  0.364488
# 110  14650525  2022-04-25 00:01:07  29999057          1   30000000  0.999969
# 111  14650526  2022-04-25 00:01:32  24409144          0   30000000  0.813638
# 112  14650527  2022-04-25 00:01:33  11884890          0   30000000  0.396163
# 113  14650528  2022-04-25 00:01:48  14355250          0   30029295  0.478042
# 114  14650529  2022-04-25 00:01:58  12767931          0   30000000  0.425598
# 115  14650530  2022-04-25 00:02:05  29994586          1   30000000  0.999820
# 116  14650531  2022-04-25 00:02:45  26943935          0   30029295  0.897255
# 117  14650532  2022-04-25 00:02:55    584927          0   30058619  0.019460
# 118  14650533  2022-04-25 00:03:26  30027900          1   30029266  0.999955
# 119  14650534  2022-04-25 00:03:29         0        NaN   30058590  0.000000
#
#      congested  theta_past  theta_past_ma10
# 100          0         NaN              NaN
# 101          0    0.000000              NaN
# 102          1    0.102343              NaN
# 103          1    0.999522              NaN
# 104          0    0.999353              NaN
# 105          0    0.519957              NaN
# 106          0    0.361485              NaN
# 107          0    0.249217              NaN
# 108          0    0.000000              NaN
# 109          0    0.617518              NaN
# 110          1    0.364488         0.421388
# 111          0    0.999969         0.521385
# 112          0    0.813638         0.592515
# 113          0    0.396163         0.532179
# 114          0    0.478042         0.480048
# 115          1    0.425598         0.470612
# 116          0    0.999820         0.534445
# 117          0    0.897255         0.599249
# 118          1    0.019460         0.601195
# 119          0    0.999955         0.639439

# %% [markdown]
# # Part IV Train and Test Split

# %%
from sklearn.model_selection import TimeSeriesSplit

# %%
tss = TimeSeriesSplit()
for train_idx, test_idx in tss.split(df):
    pass

train_df = df.filter(items=train_idx, axis=0)
test_df =  df.filter(items=test_idx, axis=0)

# %%
train_df.head()
# Out:
#      number            timestamp  gas_used congested2  gas_limit     theta  \
# 0  14650615  2022-04-25 00:22:41   3788742          0   29970705  0.126415
# 1  14650616  2022-04-25 00:22:43  29979945          1   29999972  0.999332
# 2  14650617  2022-04-25 00:23:35  29962455          1   29970677  0.999726
# 3  14650618  2022-04-25 00:23:42  29979756          1   29999944  0.999327
# 4  14650619  2022-04-25 00:23:56  23281823          0   30000000  0.776061
#
#    congested  theta_past  theta_past_ma10
# 0          0    0.991364         0.557929
# 1          1    0.126415         0.562116
# 2          1    0.999332         0.562060
# 3          1    0.999726         0.597107
# 4          0    0.999327         0.675015

# %%
test_df.head()
# Out:
#          number            timestamp  gas_used congested2  gas_limit  \
# 52875  14703290  2022-05-03 07:21:51  29913769          1   29970676
# 52876  14703291  2022-05-03 07:22:47   5183307          0   29999943
# 52877  14703292  2022-05-03 07:22:59  29986301          1   30000000
# 52878  14703293  2022-05-03 07:23:03         0        NaN   30000000
# 52879  14703294  2022-05-03 07:23:04  29965217          1   29970705
#
#           theta  congested  theta_past  theta_past_ma10
# 52875  0.998101          1    0.999458         0.579359
# 52876  0.172777          0    0.998101         0.625504
# 52877  0.999543          1    0.172777         0.633738
# 52878  0.000000          0    0.999543         0.708030
# 52879  0.999817          1    0.000000         0.608090

# %% [markdown]
# # Part IV Prepare the Train and Test Data for Classification and Regression

# %%
df_C =df[['congested','theta_past_ma10']]
df_R =df[['theta','theta_past_ma10']]

# %%
# please complete the code on your own
df_C_train=
df_C_test =

# %%
# please complete the code on your own
df_R_train=
df_R_test =

# %%
#export and save the data to the processed data folder, please complete the code on your own
